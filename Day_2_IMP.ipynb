# %% [markdown]
# MODEL PREPARATION
# ============================================================
# Training set: (227845, 30)
# Test set: (56962, 30)
# Training fraud cases: 394
# Test fraud cases: 98
#
# ============================================================
# ISOLATION FOREST MODEL
# ============================================================
# Isolation Forest Results:
#               precision    recall  f1-score   support
#
#   Legitimate       1.00      1.00      1.00     56864
#   Fraudulent       0.31      0.34      0.32        98
#
#     accuracy                           1.00     56962
#    macro avg       0.66      0.67      0.66     56962
# weighted avg       1.00      1.00      1.00     56962
#
# F1 Score (Fraud): 0.3235
# False Positives: 73
# False Negatives: 65
#
# ============================================================
# RANDOM FOREST MODEL
# ============================================================
# Random Forest Results:
#               precision    recall  f1-score   support
#
#   Legitimate       1.00      1.00      1.00     56864
#   Fraudulent       0.65      0.85      0.73        98
#
#     accuracy                           1.00     56962
#    macro avg       0.82      0.92      0.87     56962
# weighted avg       1.00      1.00      1.00     56962
#
# F1 Score (Fraud): 0.7345
# False Positives: 45
# False Negatives: 15
#
# ============================================================
# MODEL COMPARISON - F1 SCORE FOCUS
# ============================================================
#               Metric  Isolation Forest  Random Forest
# 0    False Positives         73.000000      45.000000
# 1    False Negatives         65.000000      15.000000
# 2  Precision (Fraud)          0.311321       0.648438
# 3     Recall (Fraud)          0.336735       0.846939
# 4   F1-Score (Fraud)          0.323529       0.734513
#
# ============================================================
# F1 SCORE IMPROVEMENT SIMULATION
# ============================================================
# Current Random Forest F1 Score: 0.7345
# Target F1 Score (10% improvement): 0.8080
#
# Optimal Threshold: 0.64
# Optimal F1 Score: 0.8125
# Improvement: 10.6%
# ✅ ACHIEVED 10% IMPROVEMENT!
#
# Optimal Model Results:
# False Positives: 16
# False Negatives: 20
# Precision: 0.8298
# Recall: 0.7959
# F1 Score: 0.8125
#
# ============================================================
# SUMMARY
# ============================================================
# Key Findings:
# 1. Isolation Forest F1 Score: 0.3235
# 2. Random Forest F1 Score (Default): 0.7345
# 3. Random Forest F1 Score (Optimal): 0.8125
# 4. F1 Score Improvement: 10.6%
# 5. Optimal Threshold: 0.64

# %% [markdown]
# ## also added script ot visualise forest and trees
